# %% [markdown]
# <a href="https://colab.research.google.com/github/Gajalakshmisubramani/data_Visualization_codes/blob/main/barchart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Replace these values with your actual metrics
accuracy = 93.2
precision = 83
f1_score = 79

# Plotting the metrics
labels = ['Accuracy', 'Precision', 'F1 Score']
values = [accuracy, precision, f1_score]

plt.bar(labels, values, color=['blue', 'green', 'orange'])
plt.ylim(0, 100)  # Assuming percentage values, adjust if needed
plt.title('LSTM Model Metrics')
plt.ylabel('Percentage')
plt.show()
